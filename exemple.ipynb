# %%
import ochunGRN as oGRN
GENESNB = 8
test = oGRN.Grn(GENESNB,0.1,0.2)
oGRN.plotGraph(test)

# %%
Coeff = oGRN.getCoefficient(GENESNB)
Coeff
# Out:
# {'ProtsDeg': [0.06387595132669806,
#   0.04967381673245856,
#   0.013138364570541575,
#   0.017007980305148468,
#   0.006755582126555341],
#  'mRNAsDeg': [0.141562919156466,
#   0.13291480849371196,
#   0.14534568986362745,
#   0.10878565864408424,
#   0.11277620114617984],
#  'TranscriptionsRate': [0.57, 0.46, 3.4, 12.98, 17.66],
#  'TranslationsRate': [27.99, 145.35, 1276.24, 1292.98, 300.94],
#  'mRNAAvg': [6.33, 4.89, 37.08, 174.42, 231.53],
#  'ProtAvg': [3252.62, 6069.75, 1589278.6, 7113509.84, 2601915.32]}

# %%
oGRN.simulationODEs(test, ["massAction","indirect","Hill"], (0,100),Coeff)
oGRN.plotSim(test,"test.png")
